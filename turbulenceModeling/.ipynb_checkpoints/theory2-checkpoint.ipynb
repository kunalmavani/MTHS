# %% [markdown]
# # Lecture Turbulence Modeling: Theory - Part 2
#
#
# ~

# %% [markdown]
# ### Introduction

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('J1jLbaSvfPI',width = 600,height=400)

# %% [markdown]
# ### Reynolds averaged Navier-Stokes equations

# %%
YouTubeVideo('mhWlwTf3iNk',width = 600,height=400)

# %% [markdown]
# ### Turbulence modeling closure problem & Reynolds stress transport equations

# %%
YouTubeVideo('Rb4Q-GVBGhg',width = 600,height=400)

# %% [markdown]
# ### $k-\epsilon~~$ Turbulence Model

# %%
YouTubeVideo('5GfNahfRMiQ',width = 600,height=400)

# %% [markdown]
# ### Questions and answers

# %%
YouTubeVideo('Hegy6Tznpg8',width = 600,height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/Hegy6Tznpg8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
