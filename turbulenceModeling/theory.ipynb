# %% [markdown]
# # Lecture Turbulence Modeling: Theory
#
#
# ~

# %% [markdown]
# ### Introduction

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('J1jLbaSvfPI',width = 600,height=400)

# %% [markdown]
# ### Reynolds averaged Navier-Stokes equations

# %%
YouTubeVideo('mhWlwTf3iNk',width = 600,height=400)

# %% [markdown]
# ### Turbulence modeling closure problem & Reynolds stress transport equations

# %%
YouTubeVideo('Rb4Q-GVBGhg',width = 600,height=400)

# %% [markdown]
# ### $k-\epsilon~~$ turbulence model

# %%
YouTubeVideo('5GfNahfRMiQ',width = 600,height=400)

# %% [markdown]
# ### k-$\epsilon$ applied to the channel flow (without wall damping)

# %%
YouTubeVideo('YJIrEWyUCAE',width = 600,height=400)

# %% [markdown]
# ### k-$\epsilon$ with wall damping & reliability of turbulence models

# %%
YouTubeVideo('4hVr5qO1qU8',width = 600,height=400)

# %% [markdown]
# ### 3D effects and turbulence models

# %%
YouTubeVideo('HUhemypIUZ0',width = 600,height=400)

# %% [markdown]
# ### Concluding remarks

# %%
YouTubeVideo('ZUI8a8CMUCc',width = 600,height=400)

# %% [markdown]
# ### Questions and answers

# %%
YouTubeVideo('Hegy6Tznpg8',width = 600,height=400)
